# %%
import os 
import pandas as pd
print(os.getcwd())

df = pd.read_csv("data/credits.csv", delimiter=",")
df.head()
# Out:
# c:\Users\Lolita\Desktop\pythonkursas\data_analysis_course
#    person_id       id             name                character   role
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR

# %%
df.iloc[2:4]
# Out:
#    person_id       id           name                character   role
# 2       7064  tm84618  Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618  Harvey Keitel  Matthew 'Sport' Higgins  ACTOR

# %%
df.loc[df['person_id'] < 3739]
# Out:
#        person_id         id              name  \
# 9           3308    tm84618   Martin Scorsese
# 36          3308    tm84618   Martin Scorsese
# 38          1549   tm127384       John Cleese
# 86          1549    tm70993       John Cleese
# 107         1700   tm190788     Ellen Burstyn
# ...          ...        ...               ...
# 76468       1027  tm1102410   Erin Fitzgerald
# 76546        439  tm1141346       Sam Vincent
# 76696        202   tm985747          Roy Chiu
# 77096       1350   tm996479     Parmeet Sethi
# 77159        497  tm1040816  Jolina Magdangal
#
#                                                character      role
# 9                          Passenger Watching Silhouette     ACTOR
# 36                                                   NaN  DIRECTOR
# 38     Second Swallow-Savvy Guard / The Black Knight ...     ACTOR
# 86     Wise Man #1 / Reg / Jewish Official / First Ce...     ACTOR
# 107                                        Chris MacNeil     ACTOR
# ...

# %%
df[df["name"].str.contains("John")]
# Out:
#        person_id         id                   name  \
# 38          1549   tm127384            John Cleese
# 47         11481   tm127384             John Young
# 54        589811   tm127384          Sandy Johnson
# 81          8327   tm127384          John Thornton
# 86          1549    tm70993            John Cleese
# ...          ...        ...                    ...
# 76045    1855942  tm1028026              Jipa John
# 76501     109159   ts322506         John Tartaglia
# 76716    2009096   tm985747               Johnmans
# 76933      66826  tm1036797           John Abraham
# 77203     530811  tm1098060  Toyin Aimakhu-Johnson
#
#                                                character   role
# 38     Second Swallow-Savvy Guard / The Black Knight ...  ACTOR
# 47                           Dead Body / Historian Frank  ACTOR
# 54     Knight of Ni / Villager at Witch Burning / Mus...  ACTOR
# 81                           Dancing Knight (uncredited)  ACTOR
# ...

# %%
import os 
import pandas as pd
print(os.getcwd())

df = pd.read_csv("data/titles.csv", delimiter=",")
df.head()
# Out:
# c:\Users\Lolita\Desktop\pythonkursas\data_analysis_course
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm127384      Monty Python and the Holy Grail  MOVIE
# 3   tm70993                        Life of Brian  MOVIE
# 4  tm190788                         The Exorcist  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  King Arthur, accompanied by his squire, recrui...          1975
# 3  Brian Cohen is an average young Jewish man, bu...          1979
# 4  12-year-old Regan MacNeil begins to adapt an e...          1973
#
#   age_certification  runtime                 genres production_countries  \
# 0             TV-MA       48      ['documentation']               ['US']
# ...

# %%
df.groupby(['genres']).mean().sort_values('imdb_score',ascending=False)
# Out:
#                                                     release_year  runtime  \
# genres
# ['scifi', 'family', 'fantasy', 'animation', 'ac...        2005.0     24.0
# ['drama', 'action', 'comedy', 'crime', 'animati...        2011.0     23.0
# ['scifi', 'animation', 'crime', 'drama', 'fanta...        2006.0     24.0
# ['scifi', 'action', 'drama', 'fantasy', 'horror...        2013.0     24.0
# ['western', 'action', 'scifi', 'thriller', 'ani...        1998.0     25.0
# ...                                                          ...      ...
# ['scifi', 'documentation']                                2019.0     44.0
# ['thriller', 'horror', 'european']                        2020.0     98.0
# ['thriller', 'western', 'action', 'drama', 'cri...        2022.0    108.0
# ['western', 'crime', 'thriller', 'drama']                 2019.0    199.0
# ['western']                                               2004.0     84.0
#
# ...

# %%
df.genres.unique()
# Out:
# array(["['documentation']", "['crime', 'drama']", "['comedy', 'fantasy']",
#        ..., "['crime', 'comedy', 'drama', 'thriller', 'action']",
#        "['music', 'romance', 'comedy']",
#        "['family', 'comedy', 'animation']"], dtype=object)

# %%
df.groupby(['runtime']).count()
# Out:
#          id  title  type  description  release_year  age_certification  \
# runtime
# 0        24     24    24           24            24                 16
# 2         4      4     4            4             4                  4
# 3         8      8     8            8             8                  7
# 4         5      5     5            5             5                  3
# 5         7      7     7            7             7                  7
# ...      ..    ...   ...          ...           ...                ...
# 229       1      1     1            1             1                  1
# 230       1      1     1            1             1                  0
# 235       1      1     1            1             1                  0
# 240       1      1     1            1             1                  1
# 251       1      1     1            1             1                  0
#
#          genres  production_countries  seasons  imdb_id  imdb_score  \
# runtime
# ...
